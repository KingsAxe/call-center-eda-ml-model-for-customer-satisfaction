# %% [markdown]
# #### **Overview**

# %% [markdown]
# **Steps:**
# 1. Select clustering features
# 2. Clean + impute missing values
# 3. Scale numeric columns
# 4. One-hot encode categorical columns
# 5. Vectorize topics
# 6. Combine features
# 7. Apply clustering (KMeans / GMM / HDBSCAN)

# %%
pip install hdbscan scikit-learn
# Out:
# Requirement already satisfied: hdbscan in c:\users\pc\anaconda3\lib\site-packages (0.8.41)
# Requirement already satisfied: scikit-learn in c:\users\pc\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\pc\anaconda3\lib\site-packages (from hdbscan) (2.1.3)
# Requirement already satisfied: scipy>=1.0 in c:\users\pc\anaconda3\lib\site-packages (from hdbscan) (1.15.3)
# Requirement already satisfied: joblib>=1.0 in c:\users\pc\anaconda3\lib\site-packages (from hdbscan) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\pc\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.mixture import GaussianMixture
import hdbscan

# %%
# ---- select features ----
num_features = [
    "interaction_duration_seconds",
    "speech_sentiment_score",
    "customer_satisfaction_score",
    "call_hour"
]

cat_features = [
    "call_direction",
    "call_channel",
    "call_dayofweek",
    "issue_resolved",
    "follow_up_required"
]

df_model = df_copy[num_features + cat_features].copy()

# ---- preprocessing ----
preprocessor = ColumnTransformer(
    [
        ("num", StandardScaler(), num_features),
        ("cat", OneHotEncoder(handle_unknown="ignore"), cat_features)
    ]
)

X = preprocessor.fit_transform(df_model)

# ---- HDBSCAN base clustering ----
hdb = hdbscan.HDBSCAN(
    min_cluster_size=10,
    min_samples=5,
    metric="euclidean",
    prediction_data=True
).fit(X)

df_copy["hdbscan_cluster"] = hdb.labels_

# ---- Gaussian Mixture refinement ----
valid_idx = df_copy["hdbscan_cluster"] != -1
X_valid = X[valid_idx]

gmm = GaussianMixture(
    n_components=4,
    covariance_type="full",
    random_state=42
).fit(X_valid)

df_copy["gmm_cluster"] = -1
df_copy.loc[valid_idx, "gmm_cluster"] = gmm.predict(X_valid)

# ---- SOFT CLUSTER PROBABILITY ----
probs = np.full((len(df_copy), 4), np.nan)
probs[valid_idx] = gmm.predict_proba(X_valid)

for i in range(4):
    df_copy[f"gmm_prob_{i}"] = probs[:, i]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 17
#       2 num_features = [
#       3     "interaction_duration_seconds",
#       4     "speech_sentiment_score",
#       5     "customer_satisfaction_score",
#       6     "call_hour"
#       7 ]
#       9 cat_features = [
#      10     "call_direction",
#      11     "call_channel",
#    (...)
#      14     "follow_up_required"
#      15 ]
# ---> 17 df_model = df_copy[num_features + cat_features].copy()
#      19 # ---- preprocessing ----
#      20 preprocessor = ColumnTransformer(
#      21     [
#      22         ("num", StandardScaler(), num_features),
#      23         ("cat", OneHotEncoder(handle_unknown="ignore"), cat_features)
#      24     ]
#      25 )
#
# NameError: name 'df_copy' is not defined
